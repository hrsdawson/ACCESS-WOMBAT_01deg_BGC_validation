# %% [markdown]
# # Compare BGC model output to OCCCI surface chl

# %%
import xarray as xr
import matplotlib.pyplot as plt
from glob import glob

import cosima_cookbook as cc
from cosima_cookbook import explore

# %%
from dask.distributed import Client
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:40733' processes=5 threads=10, memory=40.00 GiB>

# %% [markdown]
# OCCCI 8-day surface chl.

# %%
datadir = '/g/data/ua8/ocean_color/OCCCI/v5-0/8day/chlor_a/'
files = sorted(glob(datadir + '*/ESACCI-OC-L3S-CHLOR_A-MERGED-8D_DAILY_4km_GEO_PML_OCx-*-fv5.0.nc'))
files
# Out:
# ['/g/data/ua8/ocean_color/OCCCI/v5-0/8day/chlor_a/1997/ESACCI-OC-L3S-CHLOR_A-MERGED-8D_DAILY_4km_GEO_PML_OCx-19970829-fv5.0.nc',
#  '/g/data/ua8/ocean_color/OCCCI/v5-0/8day/chlor_a/1997/ESACCI-OC-L3S-CHLOR_A-MERGED-8D_DAILY_4km_GEO_PML_OCx-19970906-fv5.0.nc',
#  '/g/data/ua8/ocean_color/OCCCI/v5-0/8day/chlor_a/1997/ESACCI-OC-L3S-CHLOR_A-MERGED-8D_DAILY_4km_GEO_PML_OCx-19970914-fv5.0.nc',
#  '/g/data/ua8/ocean_color/OCCCI/v5-0/8day/chlor_a/1997/ESACCI-OC-L3S-CHLOR_A-MERGED-8D_DAILY_4km_GEO_PML_OCx-19970922-fv5.0.nc',
#  '/g/data/ua8/ocean_color/OCCCI/v5-0/8day/chlor_a/1997/ESACCI-OC-L3S-CHLOR_A-MERGED-8D_DAILY_4km_GEO_PML_OCx-19970930-fv5.0.nc',
#  '/g/data/ua8/ocean_color/OCCCI/v5-0/8day/chlor_a/1997/ESACCI-OC-L3S-CHLOR_A-MERGED-8D_DAILY_4km_GEO_PML_OCx-19971008-fv5.0.nc',
#  '/g/data/ua8/ocean_color/OCCCI/v5-0/8day/chlor_a/1997/ESACCI-OC-L3S-CHLOR_A-MERGED-8D_DAILY_4km_GEO_PML_OCx-19971016-fv5.0.nc',
# ...

# %%
ds = xr.open_mfdataset(files)
ds
# Out:
# <xarray.Dataset>
# Dimensions:             (time: 1120, lat: 4320, lon: 8640)
# Coordinates:
#   * lat                 (lat) float64 89.98 89.94 89.9 ... -89.9 -89.94 -89.98
#   * lon                 (lon) float64 -180.0 -179.9 -179.9 ... 179.9 179.9 180.0
#   * time                (time) datetime64[ns] 1997-09-04 ... 2021-12-27
# Data variables:
#     MERIS_nobs_sum      (time, lat, lon) float32 dask.array<chunksize=(1, 4320, 8640), meta=np.ndarray>
#     MODISA_nobs_sum     (time, lat, lon) float32 dask.array<chunksize=(1, 4320, 8640), meta=np.ndarray>
#     OLCI_nobs_sum       (time, lat, lon) float32 dask.array<chunksize=(1, 4320, 8640), meta=np.ndarray>
#     SeaWiFS_nobs_sum    (time, lat, lon) float32 dask.array<chunksize=(1, 4320, 8640), meta=np.ndarray>
#     VIIRS_nobs_sum      (time, lat, lon) float32 dask.array<chunksize=(1, 4320, 8640), meta=np.ndarray>
#     chlor_a             (time, lat, lon) float32 dask.array<chunksize=(1, 4320, 8640), meta=np.ndarray>
# ...
